# %% [markdown]
# # IMPORT DEPENDENCIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split

# %% [markdown]
# # DATASET

# %%
data = pd.read_csv('housing.csv')
print(data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB
# None

# %%
data.dropna(inplace = True)
print(data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB
# None

# %%
x = data.drop(['median_house_value'], axis = 1)
y = data['median_house_value']

# %%
print(x,y)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns] 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %%
tr_data = X_train.join(y_train)
print(tr_data)
tr_data.hist(figsize = (15,10))
tr_data.plot(figsize = (15,10))
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1091     -121.81     39.71                18.0       1222.0           250.0
# 8333     -118.31     33.93                37.0       1282.0           244.0
# 20488    -118.68     34.28                 5.0       6150.0          1265.0
# 8092     -118.22     33.82                30.0       1680.0           469.0
# 14308    -117.13     32.71                37.0       1220.0           325.0
# ...          ...       ...                 ...          ...             ...
# 460      -122.26     37.87                52.0       1087.0           371.0
# 6637     -118.14     34.16                39.0       2776.0           840.0
# 51       -122.27     37.82                43.0       1868.0           456.0
# 19121    -122.64     38.24                40.0       1974.0           410.0
# 1110     -121.63     39.82                11.0       3974.0           727.0
#
#        population  households  median_income ocean_proximity  \
# 1091        708.0       281.0         2.0288          INLAND
# 8333        852.0       249.0         4.2917       <1H OCEAN
# 20488      3188.0      1266.0         4.7034       <1H OCEAN
# 8092       1779.0       429.0         3.6086      NEAR OCEAN
# 14308      1472.0       323.0         1.8250      NEAR OCEAN
# ...           ...         ...            ...             ...
# 460        3337.0       350.0         1.4012        NEAR BAY
# 6637       2546.0       773.0         2.5750       <1H OCEAN
# 51         1061.0       407.0         1.5045        NEAR BAY
# 19121      1039.0       398.0         3.7917       <1H OCEAN
# 1110       1610.0       634.0         2.6147          INLAND
#
#        median_house_value
# 1091             116700.0
# 8333             127900.0
# 20488            223000.0
# 8092             146300.0
# 14308             81500.0
# ...                   ...
# 460              175000.0
# 6637             153500.0
# 51                93800.0
# 19121            151600.0
# 1110             107700.0
#
# [16346 rows x 10 columns]
# <Axes: >

# %%
tr_data.corr()
# Out:
# C:\Users\iamar\AppData\Local\Temp\ipykernel_21028\280744181.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tr_data.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925319           -0.111313     0.045092
# latitude            -0.925319  1.000000            0.014241    -0.036450
# housing_median_age  -0.111313  0.014241            1.000000    -0.362026
# total_rooms          0.045092 -0.036450           -0.362026     1.000000
# total_bedrooms       0.069831 -0.068094           -0.321257     0.931396
# population           0.099151 -0.108029           -0.295885     0.854207
# households           0.056364 -0.072515           -0.303799     0.919667
# median_income       -0.012098 -0.081234           -0.118270     0.194103
# median_house_value  -0.040294 -0.147605            0.106035     0.132194
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069831    0.099151    0.056364      -0.012098
# latitude                 -0.068094   -0.108029   -0.072515      -0.081234
# housing_median_age       -0.321257   -0.295885   -0.303799      -0.118270
# total_rooms               0.931396    0.854207    0.919667       0.194103
# total_bedrooms            1.000000    0.873632    0.979096      -0.009527
# population                0.873632    1.000000    0.904023       0.002183
# households                0.979096    0.904023    1.000000       0.012087
# median_income            -0.009527    0.002183    0.012087       1.000000
# median_house_value        0.051378   -0.024612    0.067003       0.688019
#
#                     median_house_value
# longitude                    -0.040294
# latitude                     -0.147605
# housing_median_age            0.106035
# total_rooms                   0.132194
# total_bedrooms                0.051378
# population                   -0.024612
# households                    0.067003
# median_income                 0.688019
# median_house_value            1.000000

# %%
plt.figsize = (15,10)
sns.heatmap(tr_data.corr(), annot= True, cmap = "RdYlBu")
# Out:
# C:\Users\iamar\AppData\Local\Temp\ipykernel_21028\683859235.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tr_data.corr(), annot= True, cmap = "RdYlBu")
# <Axes: >

# %%
tr_data['total_rooms'] = np.log(tr_data['total_rooms'] + 1)
tr_data['total_bedrooms'] = np.log(tr_data['total_bedrooms'] + 1)
tr_data['population'] = np.log(tr_data['population'] + 1)
tr_data['households'] = np.log(tr_data['households'] + 1)

# %%
tr_data.hist(figsize = (15,10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
tr_data.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     7247
# INLAND        5191
# NEAR OCEAN    2106
# NEAR BAY      1799
# ISLAND           3
# Name: ocean_proximity, dtype: int64

# %%
tr_data = tr_data.join(pd.get_dummies(tr_data.ocean_proximity)).drop(['ocean_proximity'], axis = 1)

# %%
tr_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1091     -121.81     39.71                18.0     7.109062        5.525453
# 8333     -118.31     33.93                37.0     7.156956        5.501258
# 20488    -118.68     34.28                 5.0     8.724370        7.143618
# 8092     -118.22     33.82                30.0     7.427144        6.152733
# 14308    -117.13     32.71                37.0     7.107425        5.786897
# ...          ...       ...                 ...          ...             ...
# 460      -122.26     37.87                52.0     6.992096        5.918894
# 6637     -118.14     34.16                39.0     7.929126        6.734592
# 51       -122.27     37.82                43.0     7.533159        6.124683
# 19121    -122.64     38.24                40.0     7.588324        6.018593
# 1110     -121.63     39.82                11.0     8.287780        6.590301
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 1091     6.563856    5.641907         2.0288            116700.0          0
# 8333     6.748760    5.521461         4.2917            127900.0          1
# 20488    8.067463    7.144407         4.7034            223000.0          1
# 8092     7.484369    6.063785         3.6086            146300.0          0
# 14308    7.295056    5.780744         1.8250             81500.0          0
# ...           ...         ...            ...                 ...        ...
# 460      8.113127    5.860786         1.4012            175000.0          0
# 6637     7.842671    6.651572         2.5750            153500.0          1
# 51       6.967909    6.011267         1.5045             93800.0          0
# 19121    6.946976    5.988961         3.7917            151600.0          1
# 1110     7.384610    6.453625         2.6147            107700.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 1091        1       0         0           0
# 8333        0       0         0           0
# 20488       0       0         0           0
# 8092        0       0         0           1
# 14308       0       0         0           1
# ...       ...     ...       ...         ...
# 460         0       0         1           0
# 6637        0       0         0           0
# 51          0       0         1           0
# 19121       0       0         0           0
# 1110        1       0         0           0
#
# [16346 rows x 14 columns]
