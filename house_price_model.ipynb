# %% [markdown]
# # IMPORT DEPENDENCIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split

# %% [markdown]
# # DATASET

# %%
data = pd.read_csv('housing.csv')
print(data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB
# None

# %%
data.dropna(inplace = True)
print(data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB
# None

# %%
x = data.drop(['median_house_value'], axis = 1)
y = data['median_house_value']

# %%
print(x,y)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns] 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %%
tr_data = X_train.join(y_train)
print(tr_data)
tr_data.hist(figsize = (15,10))
tr_data.plot(figsize = (15,10))
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12779    -121.42     38.65                21.0       2274.0           495.0
# 13524    -117.28     34.17                26.0       3728.0           888.0
# 17191    -122.38     37.18                52.0       1746.0           315.0
# 5318     -118.42     34.06                44.0        533.0            90.0
# 1167     -121.56     39.51                46.0       1885.0           385.0
# ...          ...       ...                 ...          ...             ...
# 16806    -122.41     37.66                34.0       1075.0           318.0
# 6281     -117.92     34.03                32.0       1819.0           375.0
# 8138     -118.10     33.83                36.0       1408.0           250.0
# 13883    -117.27     34.45                 8.0       6463.0          1095.0
# 8655     -118.42     33.85                43.0       1584.0           477.0
#
#        population  households  median_income ocean_proximity  \
# 12779      1157.0       445.0         2.0980          INLAND
# 13524      1765.0       727.0         1.7456          INLAND
# 17191       941.0       220.0         3.3047      NEAR OCEAN
# 5318        291.0        97.0        10.8045       <1H OCEAN
# 1167        871.0       347.0         1.6352          INLAND
# ...           ...         ...            ...             ...
# 16806       906.0       294.0         3.0052      NEAR OCEAN
# 6281       1728.0       375.0         3.9750       <1H OCEAN
# 8138        702.0       251.0         4.8750       <1H OCEAN
# 13883      3213.0      1031.0         3.2215          INLAND
# 8655        799.0       433.0         5.0322      NEAR OCEAN
#
#        median_house_value
# 12779             49800.0
# 13524             86800.0
# 17191            286100.0
# 5318             500001.0
# 1167              53100.0
# ...                   ...
# 16806            242500.0
# 6281             162400.0
# 8138             222500.0
# 13883            108800.0
# 8655             435000.0
#
# [16346 rows x 10 columns]
# <Axes: >

# %%
tr_data.corr()
# Out:
# C:\Users\iamar\AppData\Local\Temp\ipykernel_3916\280744181.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tr_data.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924644           -0.104547     0.048735
# latitude            -0.924644  1.000000            0.007892    -0.038516
# housing_median_age  -0.104547  0.007892            1.000000    -0.364647
# total_rooms          0.048735 -0.038516           -0.364647     1.000000
# total_bedrooms       0.072236 -0.068710           -0.322822     0.929391
# population           0.101343 -0.109341           -0.295035     0.853706
# households           0.059722 -0.074122           -0.304313     0.917927
# median_income       -0.014748 -0.080003           -0.118000     0.200175
# median_house_value  -0.042367 -0.147344            0.106781     0.131708
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.072236    0.101343    0.059722      -0.014748
# latitude                 -0.068710   -0.109341   -0.074122      -0.080003
# housing_median_age       -0.322822   -0.295035   -0.304313      -0.118000
# total_rooms               0.929391    0.853706    0.917927       0.200175
# total_bedrooms            1.000000    0.874788    0.979898      -0.007033
# population                0.874788    1.000000    0.904077       0.005074
# households                0.979898    0.904077    1.000000       0.014270
# median_income            -0.007033    0.005074    0.014270       1.000000
# median_house_value        0.047370   -0.027651    0.062963       0.689176
#
#                     median_house_value
# longitude                    -0.042367
# latitude                     -0.147344
# housing_median_age            0.106781
# total_rooms                   0.131708
# total_bedrooms                0.047370
# population                   -0.027651
# households                    0.062963
# median_income                 0.689176
# median_house_value            1.000000

# %%
plt.figsize = (15,10)
sns.heatmap(tr_data.corr(), annot= True, cmap = "RdYlBu")
# Out:
# C:\Users\iamar\AppData\Local\Temp\ipykernel_3916\683859235.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tr_data.corr(), annot= True, cmap = "RdYlBu")
# <Axes: >

# %%
tr_data['total_rooms'] = np.log(tr_data['total_rooms'] + 1)
tr_data['total_bedrooms'] = np.log(tr_data['total_bedrooms'] + 1)
tr_data['population'] = np.log(tr_data['population'] + 1)
tr_data['households'] = np.log(tr_data['households'] + 1)

# %%
tr_data.hist(figsize = (15,10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
tr_data.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     7244
# INLAND        5190
# NEAR OCEAN    2111
# NEAR BAY      1796
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
tr_data = tr_data.join(pd.get_dummies(tr_data.ocean_proximity)).drop(['ocean_proximity'], axis = 1)

# %%
tr_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12779    -121.42     38.65                21.0     7.729735        6.206576
# 13524    -117.28     34.17                26.0     8.223895        6.790097
# 17191    -122.38     37.18                52.0     7.465655        5.755742
# 5318     -118.42     34.06                44.0     6.280396        4.510860
# 1167     -121.56     39.51                46.0     7.542213        5.955837
# ...          ...       ...                 ...          ...             ...
# 16806    -122.41     37.66                34.0     6.981006        5.765191
# 6281     -117.92     34.03                32.0     7.506592        5.929589
# 8138     -118.10     33.83                36.0     7.250636        5.525453
# 13883    -117.27     34.45                 8.0     8.774004        6.999422
# 8655     -118.42     33.85                43.0     7.368340        6.169611
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 12779    7.054450    6.100319         2.0980             49800.0          0
# 13524    7.476472    6.590301         1.7456             86800.0          0
# 17191    6.848005    5.398163         3.3047            286100.0          0
# 5318     5.676754    4.584967        10.8045            500001.0          1
# 1167     6.770789    5.852202         1.6352             53100.0          0
# ...           ...         ...            ...                 ...        ...
# 16806    6.810142    5.686975         3.0052            242500.0          0
# 6281     7.455298    5.929589         3.9750            162400.0          1
# 8138     6.555357    5.529429         4.8750            222500.0          1
# 13883    8.075272    6.939254         3.2215            108800.0          0
# 8655     6.684612    6.073045         5.0322            435000.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 12779       1       0         0           0
# 13524       1       0         0           0
# 17191       0       0         0           1
# 5318        0       0         0           0
# 1167        1       0         0           0
# ...       ...     ...       ...         ...
# 16806       0       0         0           1
# 6281        0       0         0           0
# 8138        0       0         0           0
# 13883       1       0         0           0
# 8655        0       0         0           1
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize = (15,10))
sns.scatterplot(x = 'latitude',y = 'longitude',data = tr_data,hue = 'median_house_value',palette = 'coolwarm')
## blue == less expensive ,, red == more e
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>
